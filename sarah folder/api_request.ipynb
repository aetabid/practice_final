# %% [markdown]
# data website link: https://data.cityofnewyork.us/Public-Safety/EMS-Incident-Dispatch-Data/76xm-jjuj/about_data
#
# dataset ID: 76xm-jjuj
#
# Socrata API endpoint: https://data.cityofnewyork.us/resource/76xm-jjuj.csv

# %%
import requests
import pandas as pd
from io import StringIO

# %%
dfs = []

for offset in range(0, 200000, 50000):
    base_url = "https://data.cityofnewyork.us/resource/76xm-jjuj.csv"

    params = {
        "$select": "incident_datetime,borough,zipcode,"
                "initial_call_type,initial_severity_level_code,"
                "policeprecinct,communitydistrict,congressionaldistrict,"
                "incident_travel_tm_seconds_qy",
        "$where": "incident_datetime between '2023-01-01T00:00:00' and '2023-03-31T23:59:59' "
                "AND incident_travel_tm_seconds_qy IS NOT NULL",
        "$limit": 50000
    }

# %%
"""response = requests.get(base_url, params=params)
df = pd.read_csv(StringIO(response.text), parse_dates=["incident_datetime"])"""

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   incident_datetime              50000 non-null  datetime64[us]
#  1   borough                        50000 non-null  str
#  2   zipcode                        49653 non-null  float64
#  3   initial_call_type              50000 non-null  str
#  4   initial_severity_level_code    50000 non-null  int64
#  5   policeprecinct                 49654 non-null  float64
#  6   communitydistrict              49654 non-null  float64
#  7   congressionaldistrict          49654 non-null  float64
#  8   incident_travel_tm_seconds_qy  50000 non-null  int64
# dtypes: datetime64[us](1), float64(4), int64(2), str(2)
# memory usage: 3.4 MB
