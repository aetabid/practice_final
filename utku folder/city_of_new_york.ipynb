# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore

# %%
#url = "https://data.cityofnewyork.us/resource/76xm-jjuj.csv?$limit=60000"
#main_df1 = pd.read_csv(url)

#main_df1.head()

# %%
#main_df1.isna().sum()

# %%
#main_df1.columns

# %%
#main_df1['dispatch_response_seconds_qy']

# %%
#import pickle

#with open("nyc_911_calls.pkl", "wb") as f:
    #pickle.dump(main_df1, f)

# %%
#with open("nyc_911_calls.pkl", "rb") as f:
 #   df = pickle.load(f)

#df.to_csv("nyc_911_calls.csv", index=False)

# %%
main_df = pd.read_csv("nyc_911_calls.csv")

# %%
main_df
# Out:
#        cad_incident_id        incident_datetime initial_call_type  \
# 0            230010001  2023-01-01T00:00:02.000            UNKNOW
# 1            230010002  2023-01-01T00:00:16.000            RESPFC
# 2            230010003  2023-01-01T00:00:30.000            DIFFFC
# 3            230010004  2023-01-01T00:01:35.000            INJURY
# 4            230010007  2023-01-01T00:01:55.000              DRUG
# ...                ...                      ...               ...
# 59995        230143182  2023-01-14T18:13:18.000            UNKNOW
# 59996        230143183  2023-01-14T18:13:31.000               EDP
# 59997        230143184  2023-01-14T18:13:54.000            UNKNOW
# 59998        230143185  2023-01-14T18:13:59.000              SICK
# 59999        230143187  2023-01-14T18:14:35.000            STATEP
#
#        initial_severity_level_code final_call_type  final_severity_level_code  \
# 0                                4          UNKNOW                          4
# 1                                4          RESPFC                          4
# 2                                2          DIFFFC                          2
# 3                                5          INJURY                          5
# 4                                4            DRUG                          4
# ...                            ...             ...                        ...
# 59995                            4          UNKNOW                          4
# 59996                            7             EDP                          7
# 59997                            4          UNKNOW                          4
# 59998                            6            SICK                          6
# 59999                            2          STATEP                          2
#
#       first_assignment_datetime valid_dispatch_rspns_time_indc  \
# 0       2023-01-01T00:23:32.000                              Y
# 1       2023-01-01T00:01:22.000                              Y
# 2       2023-01-01T00:02:24.000                              Y
# 3       2023-01-01T01:03:40.000                              Y
# 4       2023-01-01T00:23:42.000                              Y
# ...                         ...                            ...
# 59995   2023-01-14T18:13:36.000                              Y
# 59996   2023-01-14T18:13:52.000                              Y
# 59997   2023-01-14T18:15:12.000                              Y
# 59998   2023-01-14T18:14:12.000                              Y
# 59999   2023-01-14T18:14:46.000                              Y
#
#        dispatch_response_seconds_qy first_activation_datetime  ...  zipcode  \
# 0                              1410   2023-01-01T00:23:47.000  ...  10128.0
# 1                                66   2023-01-01T01:42:19.000  ...  11221.0
# 2                               114   2023-01-01T00:02:33.000  ...  10463.0
# 3                              3725   2023-01-01T01:03:40.000  ...  10018.0
# 4                              1307   2023-01-01T00:23:55.000  ...  10034.0
# ...                             ...                       ...  ...      ...
# 59995                            18   2023-01-14T18:14:10.000  ...  11208.0
# 59996                            21   2023-01-14T18:14:00.000  ...  10007.0
# 59997                            78   2023-01-14T18:18:03.000  ...  11212.0
# 59998                            13   2023-01-14T18:14:19.000  ...  10304.0
# 59999                            11   2023-01-14T18:15:34.000  ...  11434.0
#
#       policeprecinct  citycouncildistrict  communitydistrict  \
# 0               19.0                  4.0              108.0
# 1               79.0                 36.0              303.0
# 2               52.0                 14.0              207.0
# 3               14.0                  3.0              104.0
# 4               34.0                 10.0              112.0
# ...              ...                  ...                ...
# 59995           75.0                 42.0              305.0
# 59996            5.0                  1.0              101.0
# 59997           73.0                 41.0              316.0
# 59998          120.0                 49.0              501.0
# 59999          113.0                 28.0              412.0
#
#       communityschooldistrict congressionaldistrict reopen_indicator  \
# 0                         2.0                  12.0                Y
# 1                        16.0                   8.0                N
# 2                        10.0                  13.0                N
# 3                         2.0                  10.0                N
# 4                         6.0                  13.0                N
# ...                       ...                   ...              ...
# 59995                    19.0                   8.0                N
# 59996                     2.0                   7.0                N
# 59997                    23.0                   9.0                N
# 59998                    31.0                  11.0                N
# 59999                    27.0                   5.0                N
#
#       special_event_indicator standby_indicator transfer_indicator
# 0                           N                 N                  N
# 1                           N                 N                  N
# 2                           N                 N                  N
# 3                           N                 N                  N
# 4                           N                 N                  N
# ...                       ...               ...                ...
# 59995                       N                 N                  N
# 59996                       N                 N                  N
# 59997                       N                 N                  N
# 59998                       N                 N                  N
# 59999                       N                 N                  N
#
# [60000 rows x 31 columns]

# %%
main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Data columns (total 31 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   cad_incident_id                 60000 non-null  int64
#  1   incident_datetime               60000 non-null  object
#  2   initial_call_type               60000 non-null  object
#  3   initial_severity_level_code     60000 non-null  int64
#  4   final_call_type                 60000 non-null  object
#  5   final_severity_level_code       60000 non-null  int64
#  6   first_assignment_datetime       59223 non-null  object
#  7   valid_dispatch_rspns_time_indc  60000 non-null  object
#  8   dispatch_response_seconds_qy    60000 non-null  int64
#  9   first_activation_datetime       59126 non-null  object
#  10  first_on_scene_datetime         57362 non-null  object
#  11  valid_incident_rspns_time_indc  60000 non-null  object
#  12  incident_response_seconds_qy    57358 non-null  float64
#  13  incident_travel_tm_seconds_qy   57362 non-null  float64
#  14  first_to_hosp_datetime          38225 non-null  object
#  15  first_hosp_arrival_datetime     38053 non-null  object
#  16  incident_close_datetime         60000 non-null  object
#  17  held_indicator                  60000 non-null  object
#  18  incident_disposition_code       60000 non-null  object
#  19  borough                         60000 non-null  object
#  20  incident_dispatch_area          60000 non-null  object
#  21  zipcode                         59472 non-null  float64
#  22  policeprecinct                  59473 non-null  float64
#  23  citycouncildistrict             59473 non-null  float64
#  24  communitydistrict               59473 non-null  float64
#  25  communityschooldistrict         59442 non-null  float64
#  26  congressionaldistrict           59473 non-null  float64
#  27  reopen_indicator                60000 non-null  object
#  28  special_event_indicator         60000 non-null  object
#  29  standby_indicator               60000 non-null  object
#  30  transfer_indicator              60000 non-null  object
# dtypes: float64(8), int64(4), object(19)
# memory usage: 14.2+ MB

# %%
main_df['cad_incident_id']
# Out:
# 0        230010001
# 1        230010002
# 2        230010003
# 3        230010004
# 4        230010007
#            ...
# 59995    230143182
# 59996    230143183
# 59997    230143184
# 59998    230143185
# 59999    230143187
# Name: cad_incident_id, Length: 60000, dtype: int64

# %%
main_df['first_assignment_datetime']
# Out:
# 0        2023-01-01T00:23:32.000
# 1        2023-01-01T00:01:22.000
# 2        2023-01-01T00:02:24.000
# 3        2023-01-01T01:03:40.000
# 4        2023-01-01T00:23:42.000
#                   ...
# 59995    2023-01-14T18:13:36.000
# 59996    2023-01-14T18:13:52.000
# 59997    2023-01-14T18:15:12.000
# 59998    2023-01-14T18:14:12.000
# 59999    2023-01-14T18:14:46.000
# Name: first_assignment_datetime, Length: 60000, dtype: object

# %%
main_df['first_activation_datetime']
# Out:
# 0        2023-01-01T00:23:47.000
# 1        2023-01-01T01:42:19.000
# 2        2023-01-01T00:02:33.000
# 3        2023-01-01T01:03:40.000
# 4        2023-01-01T00:23:55.000
#                   ...
# 59995    2023-01-14T18:14:10.000
# 59996    2023-01-14T18:14:00.000
# 59997    2023-01-14T18:18:03.000
# 59998    2023-01-14T18:14:19.000
# 59999    2023-01-14T18:15:34.000
# Name: first_activation_datetime, Length: 60000, dtype: object

# %%
main_df['dispatch_response_seconds_qy']
# Out:
# 0        1410
# 1          66
# 2         114
# 3        3725
# 4        1307
#          ...
# 59995      18
# 59996      21
# 59997      78
# 59998      13
# 59999      11
# Name: dispatch_response_seconds_qy, Length: 60000, dtype: int64

# %%
main_df['first_assignment_datetime']
# Out:
# 0        2023-01-01T00:23:32.000
# 1        2023-01-01T00:01:22.000
# 2        2023-01-01T00:02:24.000
# 3        2023-01-01T01:03:40.000
# 4        2023-01-01T00:23:42.000
#                   ...
# 59995    2023-01-14T18:13:36.000
# 59996    2023-01-14T18:13:52.000
# 59997    2023-01-14T18:15:12.000
# 59998    2023-01-14T18:14:12.000
# 59999    2023-01-14T18:14:46.000
# Name: first_assignment_datetime, Length: 60000, dtype: object

# %%
main_df['incident_datetime']
# Out:
# 0        2023-01-01T00:00:02.000
# 1        2023-01-01T00:00:16.000
# 2        2023-01-01T00:00:30.000
# 3        2023-01-01T00:01:35.000
# 4        2023-01-01T00:01:55.000
#                   ...
# 59995    2023-01-14T18:13:18.000
# 59996    2023-01-14T18:13:31.000
# 59997    2023-01-14T18:13:54.000
# 59998    2023-01-14T18:13:59.000
# 59999    2023-01-14T18:14:35.000
# Name: incident_datetime, Length: 60000, dtype: object

# %%
main_df.columns
# Out:
# Index(['cad_incident_id', 'incident_datetime', 'initial_call_type',
#        'initial_severity_level_code', 'final_call_type',
#        'final_severity_level_code', 'first_assignment_datetime',
#        'valid_dispatch_rspns_time_indc', 'dispatch_response_seconds_qy',
#        'first_activation_datetime', 'first_on_scene_datetime',
#        'valid_incident_rspns_time_indc', 'incident_response_seconds_qy',
#        'incident_travel_tm_seconds_qy', 'first_to_hosp_datetime',
#        'first_hosp_arrival_datetime', 'incident_close_datetime',
#        'held_indicator', 'incident_disposition_code', 'borough',
#        'incident_dispatch_area', 'zipcode', 'policeprecinct',
#        'citycouncildistrict', 'communitydistrict', 'communityschooldistrict',
#        'congressionaldistrict', 'reopen_indicator', 'special_event_indicator',
#        'standby_indicator', 'transfer_indicator'],
#       dtype='object')

# %%
main_df['valid_dispatch_rspns_time_indc'].value_counts()
# Out:
# valid_dispatch_rspns_time_indc
# Y    59218
# N      782
# Name: count, dtype: int64

# %% [markdown]
# # i am looking for a response time trend analiyst
# # see that each year the reponse time
# ## in this analyst i am using  Time index: incident_datetime
# ## Target:incident_response_seconds_qy

# %%
time_df = main_df[["incident_datetime","incident_response_seconds_qy"]].copy()

# %%
time_df.head()
# Out:
#          incident_datetime  incident_response_seconds_qy
# 0  2023-01-01T00:00:02.000                        1887.0
# 1  2023-01-01T00:00:16.000                        7365.0
# 2  2023-01-01T00:00:30.000                         479.0
# 3  2023-01-01T00:01:35.000                        3725.0
# 4  2023-01-01T00:01:55.000                        2108.0

# %%
time_df['incident_datetime'] = pd.to_datetime(time_df['incident_datetime'])

# %%
sns.histplot(time_df['incident_response_seconds_qy'])
plt.grid()

# %%
plt.figure(figsize=(9,7))
sns.boxplot(y=time_df['incident_response_seconds_qy'])
plt.title("Boxplot of Incident Response Time")
plt.ylabel("Response Time (seconds)")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x=time_df['incident_datetime'].dt.year,y=time_df['incident_response_seconds_qy'])
plt.xticks(rotation=45)
plt.title("Response Time Distribution by Year")
plt.xlabel("Year")
plt.ylabel("Response Time (seconds)")
plt.show()

# %%
time_df.isna().sum()
# Out:
# incident_datetime                  0
# incident_response_seconds_qy    2642
# dtype: int64

# %%
time_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Data columns (total 2 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   incident_datetime             60000 non-null  datetime64[ns]
#  1   incident_response_seconds_qy  57358 non-null  float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 937.6 KB

# %%
time_df['incident_datetime']= pd.to_datetime(main_df['incident_datetime'])

# %%
time_df.head()
# Out:
#     incident_datetime  incident_response_seconds_qy
# 0 2023-01-01 00:00:02                        1887.0
# 1 2023-01-01 00:00:16                        7365.0
# 2 2023-01-01 00:00:30                         479.0
# 3 2023-01-01 00:01:35                        3725.0
# 4 2023-01-01 00:01:55                        2108.0

# %%
time_df.nunique()
# Out:
# incident_datetime               58615
# incident_response_seconds_qy     3756
# dtype: int64

# %%
sns.lineplot(data=time_df,x='incident_datetime',y='incident_response_seconds_qy')
# Out:
# <Axes: xlabel='incident_datetime', ylabel='incident_response_seconds_qy'>

# %%
sns.lineplot(data=time_df,x='incident_datetime',y='incident_response_seconds_qy')
plt.xlim(pd.to_datetime("2006-01-01"),pd.to_datetime("2006-03-30"))
plt.ylim(0,1000)
# Out:
# (0.0, 1000.0)

# %% [markdown]
# # I initially wanted to look at the fluctuation in 2006

# %%
(time_df['incident_response_seconds_qy']==0 ).sum()
# Out:
# np.int64(426)

# %% [markdown]
# ## Response time values equal to 0 are not meaningful in practice, so they were considered missing and replaced with NaN during EDA.

# %%
time_df['incident_response_seconds_qy'] = time_df['incident_response_seconds_qy'].replace(0,np.nan)

# %%
time_df.isna().sum()
# Out:
# incident_datetime                  0
# incident_response_seconds_qy    3068
# dtype: int64

# %%
sns.lineplot(data=time_df,x='incident_datetime',y='incident_response_seconds_qy')
plt.xlim(pd.to_datetime("2006-01-01"),pd.to_datetime("2006-01-21"))
plt.ylim(0,1000)
plt.xticks(rotation=45)
# Out:
# (array([13149., 13151., 13153., 13155., 13157., 13159., 13161., 13163.,
#         13165., 13167., 13169.]),
#  [Text(13149.0, 0, '2006-01-01'),
#   Text(13151.0, 0, '2006-01-03'),
#   Text(13153.0, 0, '2006-01-05'),
#   Text(13155.0, 0, '2006-01-07'),
#   Text(13157.0, 0, '2006-01-09'),
#   Text(13159.0, 0, '2006-01-11'),
#   Text(13161.0, 0, '2006-01-13'),
#   Text(13163.0, 0, '2006-01-15'),
#   Text(13165.0, 0, '2006-01-17'),
#   Text(13167.0, 0, '2006-01-19'),
#   Text(13169.0, 0, '2006-01-21')])

# %%
time_df['incident_travel_tm_seconds_qy'] = main_df['incident_travel_tm_seconds_qy'].copy()

# %%
time_df
# Out:
#         incident_datetime  incident_response_seconds_qy  \
# 0     2023-01-01 00:00:02                        1887.0
# 1     2023-01-01 00:00:16                        7365.0
# 2     2023-01-01 00:00:30                         479.0
# 3     2023-01-01 00:01:35                        3725.0
# 4     2023-01-01 00:01:55                        2108.0
# ...                   ...                           ...
# 59995 2023-01-14 18:13:18                         285.0
# 59996 2023-01-14 18:13:31                         537.0
# 59997 2023-01-14 18:13:54                         636.0
# 59998 2023-01-14 18:13:59                         158.0
# 59999 2023-01-14 18:14:35                         502.0
#
#        incident_travel_tm_seconds_qy
# 0                              477.0
# 1                             7299.0
# 2                              365.0
# 3                                0.0
# 4                              801.0
# ...                              ...
# 59995                          267.0
# 59996                          516.0
# 59997                          558.0
# 59998                          145.0
# 59999                          491.0
#
# [60000 rows x 3 columns]

# %%
(time_df['incident_travel_tm_seconds_qy']==0).sum()
# Out:
# np.int64(525)

# %%
time_df['incident_travel_tm_seconds_qy'] = time_df['incident_travel_tm_seconds_qy'].replace(0,np.nan)

# %%
sns.lineplot(data=time_df,x='incident_datetime',y='incident_travel_tm_seconds_qy')
# Out:
# <Axes: xlabel='incident_datetime', ylabel='incident_travel_tm_seconds_qy'>

# %%
sns.lineplot(data=time_df,x='incident_datetime',y='incident_response_seconds_qy')
plt.xlim(pd.to_datetime("2006-01-01"),pd.to_datetime("2006-01-21"))
plt.ylim(0,1500)
# Out:
# (0.0, 1500.0)

# %%
sns.lineplot(data=time_df,x='incident_datetime',y='incident_travel_tm_seconds_qy')
plt.xlim(pd.to_datetime("2006-01-01"),pd.to_datetime("2006-01-21"))
plt.ylim(0,1500)
# Out:
# (0.0, 1500.0)

# %% [markdown]
# ## NYC emergency response times in early January 2006 show sustained high variability with frequent extreme delays, indicating systemic stress rather than isolated incidents or random noise.This assumption will be tested using other available features in the dataset.

# %%
time_df['dispatch_response_seconds_qy'] = main_df['dispatch_response_seconds_qy'].copy()

# %%
time_df
# Out:
#         incident_datetime  incident_response_seconds_qy  \
# 0     2023-01-01 00:00:02                        1887.0
# 1     2023-01-01 00:00:16                        7365.0
# 2     2023-01-01 00:00:30                         479.0
# 3     2023-01-01 00:01:35                        3725.0
# 4     2023-01-01 00:01:55                        2108.0
# ...                   ...                           ...
# 59995 2023-01-14 18:13:18                         285.0
# 59996 2023-01-14 18:13:31                         537.0
# 59997 2023-01-14 18:13:54                         636.0
# 59998 2023-01-14 18:13:59                         158.0
# 59999 2023-01-14 18:14:35                         502.0
#
#        incident_travel_tm_seconds_qy  dispatch_response_seconds_qy
# 0                              477.0                          1410
# 1                             7299.0                            66
# 2                              365.0                           114
# 3                                NaN                          3725
# 4                              801.0                          1307
# ...                              ...                           ...
# 59995                          267.0                            18
# 59996                          516.0                            21
# 59997                          558.0                            78
# 59998                          145.0                            13
# 59999                          491.0                            11
#
# [60000 rows x 4 columns]

# %%
sns.lineplot(data=time_df,x='incident_datetime',y='dispatch_response_seconds_qy')
# Out:
# <Axes: xlabel='incident_datetime', ylabel='dispatch_response_seconds_qy'>

# %%
time_df.corr()
# Out:
#                                incident_datetime  \
# incident_datetime                       1.000000
# incident_response_seconds_qy            0.009481
# incident_travel_tm_seconds_qy           0.013546
# dispatch_response_seconds_qy            0.006427
#
#                                incident_response_seconds_qy  \
# incident_datetime                                  0.009481
# incident_response_seconds_qy                       1.000000
# incident_travel_tm_seconds_qy                      0.560433
# dispatch_response_seconds_qy                       0.895075
#
#                                incident_travel_tm_seconds_qy  \
# incident_datetime                                   0.013546
# incident_response_seconds_qy                        0.560433
# incident_travel_tm_seconds_qy                       1.000000
# dispatch_response_seconds_qy                        0.126152
#
#                                dispatch_response_seconds_qy
# incident_datetime                                  0.006427
# incident_response_seconds_qy                       0.895075
# incident_travel_tm_seconds_qy                      0.126152
# dispatch_response_seconds_qy                       1.000000

# %%
sns.lineplot(data=time_df,x='incident_datetime',y='dispatch_response_seconds_qy')
plt.xlim(pd.to_datetime("2006-01-01"),pd.to_datetime("2006-01-21"))
plt.ylim(0,1500)
plt.xticks(rotation=45)
# Out:
# (array([13149., 13151., 13153., 13155., 13157., 13159., 13161., 13163.,
#         13165., 13167., 13169.]),
#  [Text(13149.0, 0, '2006-01-01'),
#   Text(13151.0, 0, '2006-01-03'),
#   Text(13153.0, 0, '2006-01-05'),
#   Text(13155.0, 0, '2006-01-07'),
#   Text(13157.0, 0, '2006-01-09'),
#   Text(13159.0, 0, '2006-01-11'),
#   Text(13161.0, 0, '2006-01-13'),
#   Text(13163.0, 0, '2006-01-15'),
#   Text(13165.0, 0, '2006-01-17'),
#   Text(13167.0, 0, '2006-01-19'),
#   Text(13169.0, 0, '2006-01-21')])

# %%
time_df.isna().sum()
# Out:
# incident_datetime                   0
# incident_response_seconds_qy     3068
# incident_travel_tm_seconds_qy    3163
# dispatch_response_seconds_qy        0
# dtype: int64

# %%
(time_df['dispatch_response_seconds_qy']==0).sum()
# Out:
# np.int64(1208)

# %%
time_df['dispatch_response_seconds_qy']=time_df['dispatch_response_seconds_qy'].replace(0,np.nan)

# %%
sns.lineplot(data=time_df,x='incident_datetime',y='dispatch_response_seconds_qy')
plt.xlim(pd.to_datetime("2006-01-01"),pd.to_datetime("2006-01-21"))
plt.ylim(0,1500)
plt.xticks(rotation=45)
# Out:
# (array([13149., 13151., 13153., 13155., 13157., 13159., 13161., 13163.,
#         13165., 13167., 13169.]),
#  [Text(13149.0, 0, '2006-01-01'),
#   Text(13151.0, 0, '2006-01-03'),
#   Text(13153.0, 0, '2006-01-05'),
#   Text(13155.0, 0, '2006-01-07'),
#   Text(13157.0, 0, '2006-01-09'),
#   Text(13159.0, 0, '2006-01-11'),
#   Text(13161.0, 0, '2006-01-13'),
#   Text(13163.0, 0, '2006-01-15'),
#   Text(13165.0, 0, '2006-01-17'),
#   Text(13167.0, 0, '2006-01-19'),
#   Text(13169.0, 0, '2006-01-21')])

# %%
time_df['special_event_indicator']=main_df['special_event_indicator'].copy()

# %%
time_df['special_event_indicator'].value_counts()
# Out:
# special_event_indicator
# N    59999
# Y        1
# Name: count, dtype: int64

# %%
time_df.loc[time_df['special_event_indicator']=='Y']
# Out:
#        incident_datetime  incident_response_seconds_qy  \
# 2013 2010-01-01 00:00:21                           NaN
#
#       incident_travel_tm_seconds_qy  dispatch_response_seconds_qy  \
# 2013                          455.0                           NaN
#
#      special_event_indicator
# 2013                       Y

# %%
time_df['held_indicator']=main_df['held_indicator'].copy()

# %%
time_df['held_indicator'].value_counts()
# Out:
# held_indicator
# N    53364
# Y     6636
# Name: count, dtype: int64

# %%
sns.lineplot(data=time_df,x='incident_datetime',y=(time_df['held_indicator'] == 'Y').astype(int))
plt.xlim(pd.to_datetime("2006-01-01"),pd.to_datetime("2006-01-21"))
plt.xticks(rotation=45)
# Out:
# (array([13149., 13151., 13153., 13155., 13157., 13159., 13161., 13163.,
#         13165., 13167., 13169.]),
#  [Text(13149.0, 0, '2006-01-01'),
#   Text(13151.0, 0, '2006-01-03'),
#   Text(13153.0, 0, '2006-01-05'),
#   Text(13155.0, 0, '2006-01-07'),
#   Text(13157.0, 0, '2006-01-09'),
#   Text(13159.0, 0, '2006-01-11'),
#   Text(13161.0, 0, '2006-01-13'),
#   Text(13163.0, 0, '2006-01-15'),
#   Text(13165.0, 0, '2006-01-17'),
#   Text(13167.0, 0, '2006-01-19'),
#   Text(13169.0, 0, '2006-01-21')])

# %% [markdown]
# ## Taken together, the sustained volatility in response times, intermittent spikes in dispatch delays, and the temporal clustering of held calls suggest that early January 2006 was characterized by systemic operational stress in NYC emergency services rather than random noise or isolated incidents.

# %%
sns.lineplot(data=time_df,x='incident_datetime',y='incident_response_seconds_qy')
# Out:
# <Axes: xlabel='incident_datetime', ylabel='incident_response_seconds_qy'>

# %%
(time_df['incident_response_seconds_qy']==0).sum()
# Out:
# np.int64(0)

# %%
sns.lineplot(data=time_df,x='incident_datetime',y='incident_response_seconds_qy')
plt.xlim(pd.to_datetime("2006-01-01"),pd.to_datetime("2010-01-21"))
plt.ylim(15,6900)
# Out:
# (15.0, 6900.0)

# %%
main_df.groupby('incident_datetime')['incident_response_seconds_qy'].mean()
# Out:
# incident_datetime
# 2006-01-01T16:49:57.000      NaN
# 2006-01-02T01:34:07.000    204.0
# 2006-01-02T12:09:26.000    222.0
# 2006-01-02T15:07:11.000      NaN
# 2006-01-02T19:36:53.000      NaN
#                            ...
# 2024-10-06T05:35:33.000    519.0
# 2024-10-06T05:35:57.000      NaN
# 2024-10-06T05:36:04.000    337.0
# 2024-10-06T05:56:56.000    721.0
# 2024-10-06T05:57:50.000      NaN
# Name: incident_response_seconds_qy, Length: 58615, dtype: float64

# %%
time_df['incident_datetime']
# Out:
# 0       2023-01-01 00:00:02
# 1       2023-01-01 00:00:16
# 2       2023-01-01 00:00:30
# 3       2023-01-01 00:01:35
# 4       2023-01-01 00:01:55
#                 ...
# 59995   2023-01-14 18:13:18
# 59996   2023-01-14 18:13:31
# 59997   2023-01-14 18:13:54
# 59998   2023-01-14 18:13:59
# 59999   2023-01-14 18:14:35
# Name: incident_datetime, Length: 60000, dtype: datetime64[ns]

# %%
time_df.set_index('incident_datetime') .resample('D')['incident_response_seconds_qy'].mean()
# Out:
# incident_datetime
# 2006-01-01           NaN
# 2006-01-02    302.600000
# 2006-01-03    466.500000
# 2006-01-04    552.888889
# 2006-01-05    503.333333
#                  ...
# 2024-10-02           NaN
# 2024-10-03           NaN
# 2024-10-04           NaN
# 2024-10-05    996.653061
# 2024-10-06    739.785714
# Freq: D, Name: incident_response_seconds_qy, Length: 6854, dtype: float64

# %%
sns.lineplot(time_df.set_index('incident_datetime') .resample('H')['incident_response_seconds_qy'].mean())
plt.xlim(pd.to_datetime("2007-01-01"),pd.to_datetime("2010-01-21"))
plt.xticks(rotation=45)
# Out:
# /var/folders/34/1yg1tqgd1b96v45w9k29prnw0000gn/T/ipykernel_71278/1319922450.py:1: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   sns.lineplot(time_df.set_index('incident_datetime') .resample('H')['incident_response_seconds_qy'].mean())
# (array([13514., 13634., 13757., 13879., 14000., 14123., 14245., 14365.,
#         14488., 14610.]),
#  [Text(13514.0, 0, '2007-01'),
#   Text(13634.0, 0, '2007-05'),
#   Text(13757.0, 0, '2007-09'),
#   Text(13879.0, 0, '2008-01'),
#   Text(14000.0, 0, '2008-05'),
#   Text(14123.0, 0, '2008-09'),
#   Text(14245.0, 0, '2009-01'),
#   Text(14365.0, 0, '2009-05'),
#   Text(14488.0, 0, '2009-09'),
#   Text(14610.0, 0, '2010-01')])

# %% [markdown]
# ## The goal was to analyze the yearly distribution of incident_response_seconds_qy to check for outliers and identify extreme values.

# %%
sns.lineplot(time_df.set_index('incident_datetime') .resample('D')['incident_response_seconds_qy'].mean())
plt.xlim(pd.to_datetime("2007-01-01"),pd.to_datetime("2010-01-21"))
plt.xticks(rotation=45)
# Out:
# (array([13514., 13634., 13757., 13879., 14000., 14123., 14245., 14365.,
#         14488., 14610.]),
#  [Text(13514.0, 0, '2007-01'),
#   Text(13634.0, 0, '2007-05'),
#   Text(13757.0, 0, '2007-09'),
#   Text(13879.0, 0, '2008-01'),
#   Text(14000.0, 0, '2008-05'),
#   Text(14123.0, 0, '2008-09'),
#   Text(14245.0, 0, '2009-01'),
#   Text(14365.0, 0, '2009-05'),
#   Text(14488.0, 0, '2009-09'),
#   Text(14610.0, 0, '2010-01')])

# %%
sns.lineplot(time_df.set_index('incident_datetime') .resample('M')['incident_response_seconds_qy'].mean())
plt.xlim(pd.to_datetime("2007-01-01"),pd.to_datetime("2010-01-21"))
plt.xticks(rotation=45)
# Out:
# /var/folders/34/1yg1tqgd1b96v45w9k29prnw0000gn/T/ipykernel_71278/3437593380.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   sns.lineplot(time_df.set_index('incident_datetime') .resample('M')['incident_response_seconds_qy'].mean())
# (array([13514., 13634., 13757., 13879., 14000., 14123., 14245., 14365.,
#         14488., 14610.]),
#  [Text(13514.0, 0, '2007-01'),
#   Text(13634.0, 0, '2007-05'),
#   Text(13757.0, 0, '2007-09'),
#   Text(13879.0, 0, '2008-01'),
#   Text(14000.0, 0, '2008-05'),
#   Text(14123.0, 0, '2008-09'),
#   Text(14245.0, 0, '2009-01'),
#   Text(14365.0, 0, '2009-05'),
#   Text(14488.0, 0, '2009-09'),
#   Text(14610.0, 0, '2010-01')])

# %%
sns.lineplot(time_df.set_index('incident_datetime') .resample('Y')['incident_response_seconds_qy'].mean())
plt.xlim(pd.to_datetime("2007-01-01"),pd.to_datetime("2010-01-21"))
plt.xticks(rotation=45)
# Out:
# /var/folders/34/1yg1tqgd1b96v45w9k29prnw0000gn/T/ipykernel_71278/4010724188.py:1: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   sns.lineplot(time_df.set_index('incident_datetime') .resample('Y')['incident_response_seconds_qy'].mean())
# (array([13514., 13634., 13757., 13879., 14000., 14123., 14245., 14365.,
#         14488., 14610.]),
#  [Text(13514.0, 0, '2007-01'),
#   Text(13634.0, 0, '2007-05'),
#   Text(13757.0, 0, '2007-09'),
#   Text(13879.0, 0, '2008-01'),
#   Text(14000.0, 0, '2008-05'),
#   Text(14123.0, 0, '2008-09'),
#   Text(14245.0, 0, '2009-01'),
#   Text(14365.0, 0, '2009-05'),
#   Text(14488.0, 0, '2009-09'),
#   Text(14610.0, 0, '2010-01')])

# %% [markdown]
# ## When I look at the data hourly, daily, monthly, and yearly, the high point in 2008 disappears. This suggests that it may be an outlier, and I will check.

# %%
sns.lineplot(data=time_df,x='incident_datetime',y='incident_response_seconds_qy')
plt.xlim(pd.to_datetime("2007-12-01"),pd.to_datetime("2008-05-30"))
# Out:
# (np.float64(13848.0), np.float64(14029.0))

# %%
sns.lineplot(data=time_df,x='incident_datetime',y='incident_response_seconds_qy')
plt.xlim(pd.to_datetime("2007-12-30"),pd.to_datetime("2008-01-03"))
plt.xticks(rotation=45)
# Out:
# (array([13877. , 13877.5, 13878. , 13878.5, 13879. , 13879.5, 13880. ,
#         13880.5, 13881. ]),
#  [Text(13877.0, 0, '12-30 00'),
#   Text(13877.5, 0, '12-30 12'),
#   Text(13878.0, 0, '12-31 00'),
#   Text(13878.5, 0, '12-31 12'),
#   Text(13879.0, 0, '01-01 00'),
#   Text(13879.5, 0, '01-01 12'),
#   Text(13880.0, 0, '01-02 00'),
#   Text(13880.5, 0, '01-02 12'),
#   Text(13881.0, 0, '01-03 00')])

# %%
plt.Figure(figsize=(16,3))
sns.lineplot(data=time_df,x='incident_datetime',y='incident_response_seconds_qy')
plt.xlim(pd.to_datetime("2007-12-31 23"),pd.to_datetime("2008-01-01 01"))
plt.xticks(rotation=45)
plt.ylim(1,8500)
# Out:
# (1.0, 8500.0)

# %%
raw_2006 = time_df[(time_df['incident_datetime'].dt.year == 2006)].copy()

# %%
raw_2006.sort_values('incident_response_seconds_qy',ascending=False).head(5)
# Out:
#         incident_datetime  incident_response_seconds_qy  \
# 34067 2006-01-12 00:47:29                        1238.0
# 46517 2006-01-16 06:55:40                        1172.0
# 25961 2006-01-09 11:56:15                        1140.0
# 19352 2006-01-07 02:50:00                        1126.0
# 45227 2006-01-15 17:58:11                        1095.0
#
#        incident_travel_tm_seconds_qy  dispatch_response_seconds_qy  \
# 34067                         1215.0                          23.0
# 46517                         1049.0                         123.0
# 25961                         1125.0                          15.0
# 19352                         1081.0                          45.0
# 45227                          972.0                         123.0
#
#       special_event_indicator held_indicator
# 34067                       N              N
# 46517                       N              N
# 25961                       N              N
# 19352                       N              N
# 45227                       N              N

# %%
raw_2008 = time_df[
    (time_df['incident_datetime'].dt.year == 2008)
].copy()

# %%
raw_2008.sort_values('incident_response_seconds_qy',ascending=False).head(30)
# Out:
#         incident_datetime  incident_response_seconds_qy  \
# 21092 2008-01-01 00:05:40                        6406.0
# 29058 2008-01-01 00:07:29                        1453.0
# 28277 2008-01-01 00:07:02                        1378.0
# 20134 2008-01-01 00:23:06                        1333.0
# 30419 2008-01-01 00:07:46                         641.0
# 7400  2008-01-01 00:02:30                         632.0
# 58361 2008-01-01 00:12:26                         595.0
# 55638 2008-01-01 00:12:00                         580.0
# 36823 2008-01-01 00:08:35                         527.0
# 12574 2008-01-01 00:03:25                         495.0
# 27731 2008-01-01 00:05:59                         479.0
# 57202 2008-01-01 00:12:13                         473.0
# 13291 2008-01-01 00:03:52                         471.0
# 7026  2008-01-01 00:02:09                         463.0
# 29262 2008-01-01 00:07:35                         429.0
# 10086 2008-01-01 00:02:43                         416.0
# 36993 2008-01-01 00:08:36                         409.0
# 55127 2008-01-01 00:11:48                         377.0
# 39238 2008-01-01 00:09:37                         374.0
# 13597 2008-01-01 00:04:04                         366.0
# 10155 2008-01-01 00:02:52                         319.0
# 46247 2008-01-01 00:10:18                         281.0
# 53292 2008-01-01 00:11:10                         270.0
# 52646 2008-01-01 00:10:44                         256.0
# 40837 2008-01-01 00:10:01                         232.0
# 33555 2008-01-01 00:07:54                         226.0
# 16486 2008-01-01 00:05:19                         219.0
# 15364 2008-01-01 00:04:40                         200.0
# 33930 2008-01-01 00:08:17                         195.0
# 14754 2008-01-01 00:04:36                         160.0
#
#        incident_travel_tm_seconds_qy  dispatch_response_seconds_qy  \
# 21092                         3438.0                        2968.0
# 29058                          628.0                         825.0
# 28277                          478.0                         900.0
# 20134                         1056.0                         277.0
# 30419                          565.0                          76.0
# 7400                           601.0                          31.0
# 58361                          535.0                          60.0
# 55638                          525.0                          55.0
# 36823                          493.0                          34.0
# 12574                          363.0                         132.0
# 27731                          250.0                         229.0
# 57202                          278.0                         195.0
# 13291                          443.0                          28.0
# 7026                           444.0                          19.0
# 29262                          421.0                           8.0
# 10086                          364.0                          52.0
# 36993                          364.0                          45.0
# 55127                          346.0                          31.0
# 39238                          351.0                          23.0
# 13597                          336.0                          30.0
# 10155                          292.0                          27.0
# 46247                           97.0                         184.0
# 53292                          155.0                         115.0
# 52646                          244.0                          12.0
# 40837                          220.0                          12.0
# 33555                          176.0                          50.0
# 16486                          199.0                          20.0
# 15364                          191.0                           9.0
# 33930                          177.0                          18.0
# 14754                           97.0                          63.0
#
#       special_event_indicator held_indicator
# 21092                       N              Y
# 29058                       N              Y
# 28277                       N              Y
# 20134                       N              N
# 30419                       N              N
# 7400                        N              N
# 58361                       N              N
# 55638                       N              N
# 36823                       N              N
# 12574                       N              N
# 27731                       N              N
# 57202                       N              N
# 13291                       N              N
# 7026                        N              N
# 29262                       N              N
# 10086                       N              N
# 36993                       N              N
# 55127                       N              N
# 39238                       N              N
# 13597                       N              N
# 10155                       N              N
# 46247                       N              N
# 53292                       N              N
# 52646                       N              N
# 40837                       N              N
# 33555                       N              N
# 16486                       N              N
# 15364                       N              N
# 33930                       N              N
# 14754                       N              N

# %% [markdown]
# ## 2008 has a outlier
# ## These points are outliers in size, but they represent real delays, not data errors, so i didn’t remove them.

# %%
sns.lineplot(data=time_df,x='incident_datetime',y='incident_response_seconds_qy')
# Out:
# <Axes: xlabel='incident_datetime', ylabel='incident_response_seconds_qy'>

# %%
sns.lineplot(data=time_df,x='incident_datetime',y='incident_response_seconds_qy')
plt.xlim(pd.to_datetime("2009"),pd.to_datetime("2011"))
plt.xticks(rotation=45)
# Out:
# (array([14245., 14335., 14426., 14518., 14610., 14700., 14791., 14883.,
#         14975.]),
#  [Text(14245.0, 0, '2009-01'),
#   Text(14335.0, 0, '2009-04'),
#   Text(14426.0, 0, '2009-07'),
#   Text(14518.0, 0, '2009-10'),
#   Text(14610.0, 0, '2010-01'),
#   Text(14700.0, 0, '2010-04'),
#   Text(14791.0, 0, '2010-07'),
#   Text(14883.0, 0, '2010-10'),
#   Text(14975.0, 0, '2011-01')])

# %%
sns.lineplot(data=time_df,x='incident_datetime',y='incident_response_seconds_qy')
plt.xlim(pd.to_datetime("2010-04"),pd.to_datetime("2010-12"))
plt.xticks(rotation=45)
# Out:
# (array([14700., 14730., 14761., 14791., 14822., 14853., 14883., 14914.,
#         14944.]),
#  [Text(14700.0, 0, '2010-04'),
#   Text(14730.0, 0, '2010-05'),
#   Text(14761.0, 0, '2010-06'),
#   Text(14791.0, 0, '2010-07'),
#   Text(14822.0, 0, '2010-08'),
#   Text(14853.0, 0, '2010-09'),
#   Text(14883.0, 0, '2010-10'),
#   Text(14914.0, 0, '2010-11'),
#   Text(14944.0, 0, '2010-12')])

# %%
raw_2010 = time_df[(time_df['incident_datetime'].dt.year == 2010)
].copy()

# %%
raw_2010.sort_values('incident_response_seconds_qy',ascending=False).head(60)
# Out:
#         incident_datetime  incident_response_seconds_qy  \
# 52033 2010-08-01 04:02:14                        4958.0
# 38658 2010-08-01 01:19:09                        2011.0
# 17511 2010-07-02 13:59:59                        1500.0
# 58735 2010-08-01 04:02:52                        1144.0
# 41788 2010-08-01 02:10:48                         989.0
# 3858  2010-02-21 05:58:02                         982.0
# 31342 2010-07-31 22:59:46                         962.0
# 17752 2010-07-31 16:09:10                         858.0
# 31956 2010-08-01 00:44:38                         700.0
# 25111 2010-07-31 21:18:55                         672.0
# 51523 2010-08-01 04:02:12                         648.0
# 50537 2010-08-01 03:40:16                         641.0
# 12469 2010-04-28 22:19:31                         633.0
# 26643 2010-07-31 22:10:00                         583.0
# 10154 2010-04-23 09:12:10                         570.0
# 47168 2010-08-01 02:23:25                         531.0
# 23750 2010-07-31 20:16:06                         530.0
# 26234 2010-07-31 21:57:14                         523.0
# 20716 2010-07-31 19:08:46                         474.0
# 33724 2010-08-01 01:03:48                         443.0
# 32229 2010-08-01 01:03:03                         425.0
# 31411 2010-07-31 23:28:36                         418.0
# 27663 2010-07-31 22:32:14                         408.0
# 29398 2010-07-31 22:59:21                         404.0
# 6687  2010-02-21 05:58:26                         361.0
# 45739 2010-08-01 02:10:57                         352.0
# 11344 2010-04-28 22:18:30                         345.0
# 14279 2010-07-02 13:59:47                         341.0
# 51251 2010-08-01 03:51:54                         306.0
# 36755 2010-08-01 01:04:32                         298.0
# 69    2010-12-11 01:44:33                         286.0
# 14244 2010-06-20 02:35:18                         285.0
# 36925 2010-08-01 01:04:47                         257.0
# 27323 2010-07-31 22:21:22                         256.0
# 8930  2010-02-21 06:01:33                         249.0
# 20100 2010-07-31 16:45:20                         248.0
# 39237 2010-08-01 01:28:42                         219.0
# 213   2010-01-01 00:00:02                           NaN
# 393   2010-01-01 00:00:05                           NaN
# 430   2010-01-01 00:00:08                           NaN
# 466   2010-01-01 00:00:10                           NaN
# 574   2010-01-01 00:00:13                           NaN
# 897   2010-01-01 00:00:15                           NaN
# 2013  2010-01-01 00:00:21                           NaN
# 7196  2010-02-21 06:00:25                           NaN
# 8489  2010-02-21 06:00:32                           NaN
# 8523  2010-02-21 06:01:00                           NaN
# 34340 2010-08-01 01:04:09                           NaN
# 37095 2010-08-01 01:04:59                           NaN
# 59347 2010-08-01 04:03:03                           NaN
#
#        incident_travel_tm_seconds_qy  dispatch_response_seconds_qy  \
# 52033                          684.0                        4274.0
# 38658                         1153.0                         858.0
# 17511                         1407.0                          93.0
# 58735                         1128.0                          16.0
# 41788                          952.0                          37.0
# 3858                           596.0                         386.0
# 31342                          514.0                         448.0
# 17752                          807.0                          51.0
# 31956                          635.0                          65.0
# 25111                          651.0                          21.0
# 51523                          634.0                          14.0
# 50537                          623.0                          18.0
# 12469                          623.0                          10.0
# 26643                          573.0                          10.0
# 10154                          519.0                          51.0
# 47168                          387.0                         144.0
# 23750                          495.0                          35.0
# 26234                          341.0                         182.0
# 20716                          464.0                          10.0
# 33724                          370.0                          73.0
# 32229                          362.0                          63.0
# 31411                          370.0                          48.0
# 27663                          340.0                          68.0
# 29398                          378.0                          26.0
# 6687                           351.0                          10.0
# 45739                          336.0                          16.0
# 11344                          296.0                          49.0
# 14279                          269.0                          72.0
# 51251                          285.0                          21.0
# 36755                          253.0                          45.0
# 69                             255.0                          31.0
# 14244                          235.0                          50.0
# 36925                          249.0                           8.0
# 27323                          229.0                          27.0
# 8930                           221.0                          28.0
# 20100                          188.0                          60.0
# 39237                          180.0                          39.0
# 213                              NaN                         413.0
# 393                              NaN                           NaN
# 430                              NaN                           NaN
# 466                              NaN                           NaN
# 574                              NaN                           NaN
# 897                              NaN                           NaN
# 2013                           455.0                           NaN
# 7196                             NaN                          14.0
# 8489                             NaN                          32.0
# 8523                             NaN                          47.0
# 34340                            NaN                           NaN
# 37095                            NaN                          15.0
# 59347                            NaN                         733.0
#
#       special_event_indicator held_indicator
# 52033                       N              Y
# 38658                       N              Y
# 17511                       N              N
# 58735                       N              N
# 41788                       N              N
# 3858                        N              Y
# 31342                       N              Y
# 17752                       N              N
# 31956                       N              N
# 25111                       N              N
# 51523                       N              N
# 50537                       N              N
# 12469                       N              N
# 26643                       N              N
# 10154                       N              N
# 47168                       N              N
# 23750                       N              N
# 26234                       N              N
# 20716                       N              N
# 33724                       N              N
# 32229                       N              N
# 31411                       N              N
# 27663                       N              N
# 29398                       N              N
# 6687                        N              N
# 45739                       N              N
# 11344                       N              N
# 14279                       N              N
# 51251                       N              N
# 36755                       N              N
# 69                          N              N
# 14244                       N              N
# 36925                       N              N
# 27323                       N              N
# 8930                        N              N
# 20100                       N              N
# 39237                       N              N
# 213                         N              N
# 393                         N              N
# 430                         N              N
# 466                         N              N
# 574                         N              N
# 897                         N              N
# 2013                        Y              N
# 7196                        N              N
# 8489                        N              N
# 8523                        N              N
# 34340                       N              N
# 37095                       N              N
# 59347                       N              Y

# %%
sns.lineplot(data=time_df,x='incident_datetime',y='incident_response_seconds_qy')
plt.xlim(pd.to_datetime("2022-12-15"),pd.to_datetime("2023-02-15"))
plt.ylim(0, 10000)   
plt.xticks(rotation=45)
plt.show()

# %%
raw_2023 = time_df[
    (time_df['incident_datetime'].dt.year == 2023)
].copy()

# %%
raw_2023.sort_values('incident_response_seconds_qy',ascending=False).head(60)
# Out:
#         incident_datetime  incident_response_seconds_qy  \
# 23382 2023-01-06 00:00:06                       32022.0
# 44337 2023-01-11 00:00:10                       29011.0
# 57208 2023-01-14 00:00:22                       25995.0
# 9347  2023-01-03 00:24:29                       25554.0
# 23383 2023-01-06 00:00:09                       24039.0
# 44343 2023-01-11 00:01:32                       23449.0
# 18836 2023-01-05 00:00:13                       22899.0
# 18834 2023-01-05 00:00:07                       22694.0
# 14018 2023-01-04 00:00:52                       22369.0
# 532   2023-01-01 01:59:06                       22367.0
# 16235 2023-01-04 13:02:38                       22157.0
# 44    2023-01-01 00:20:45                       22123.0
# 16649 2023-01-04 14:38:17                       21939.0
# 9314  2023-01-03 00:13:31                       21884.0
# 27891 2023-01-07 00:01:11                       21523.0
# 48606 2023-01-12 00:40:05                       21357.0
# 40108 2023-01-10 00:09:08                       21165.0
# 57210 2023-01-14 00:00:57                       20796.0
# 554   2023-01-01 02:05:26                       20714.0
# 4227  2023-01-01 20:50:46                       20559.0
# 542   2023-01-01 02:02:11                       20355.0
# 4048  2023-01-01 20:00:54                       19430.0
# 14016 2023-01-04 00:00:39                       18950.0
# 16421 2023-01-04 13:41:59                       18671.0
# 431   2023-01-01 01:39:16                       17908.0
# 215   2023-01-01 00:55:00                       17815.0
# 17074 2023-01-04 16:07:26                       17513.0
# 581   2023-01-01 02:12:45                       17267.0
# 410   2023-01-01 01:37:04                       17128.0
# 961   2023-01-01 04:13:44                       17080.0
# 840   2023-01-01 03:35:26                       17049.0
# 44345 2023-01-11 00:02:03                       16678.0
# 555   2023-01-01 02:05:58                       16600.0
# 998   2023-01-01 04:25:03                       16428.0
# 40119 2023-01-10 00:12:29                       16373.0
# 48597 2023-01-12 00:37:10                       16335.0
# 893   2023-01-01 03:51:54                       16112.0
# 23384 2023-01-06 00:00:10                       16056.0
# 194   2023-01-01 00:50:50                       16005.0
# 180   2023-01-01 00:48:26                       15659.0
# 976   2023-01-01 04:17:18                       15393.0
# 19    2023-01-01 00:07:53                       15331.0
# 658   2023-01-01 02:34:16                       15320.0
# 603   2023-01-01 02:18:57                       15262.0
# 843   2023-01-01 03:36:43                       14971.0
# 575   2023-01-01 02:11:05                       14904.0
# 288   2023-01-01 01:09:51                       14901.0
# 83    2023-01-01 00:29:52                       14760.0
# 145   2023-01-01 00:42:10                       14722.0
# 264   2023-01-01 01:05:25                       14700.0
# 789   2023-01-01 03:16:16                       14580.0
# 55    2023-01-01 00:24:32                       14515.0
# 238   2023-01-01 01:00:49                       14482.0
# 40106 2023-01-10 00:08:10                       14480.0
# 212   2023-01-01 00:54:49                       14443.0
# 323   2023-01-01 01:17:38                       14438.0
# 340   2023-01-01 01:20:33                       14402.0
# 332   2023-01-01 01:19:30                       14363.0
# 184   2023-01-01 00:48:43                       14336.0
# 266   2023-01-01 01:05:34                       14073.0
#
#        incident_travel_tm_seconds_qy  dispatch_response_seconds_qy  \
# 23382                         5642.0                       26380.0
# 44337                         5916.0                       23095.0
# 57208                           66.0                       25929.0
# 9347                          3417.0                       22137.0
# 23383                          632.0                       23407.0
# 44343                         1083.0                       22366.0
# 18836                         1578.0                       21321.0
# 18834                         1336.0                       21358.0
# 14018                          697.0                       21672.0
# 532                          22272.0                          95.0
# 16235                          702.0                       21455.0
# 44                           10642.0                       11481.0
# 16649                         6014.0                       15925.0
# 9314                             NaN                       21884.0
# 27891                            NaN                       21523.0
# 48606                         2792.0                       18565.0
# 40108                            NaN                       21165.0
# 57210                         1379.0                       19417.0
# 554                            445.0                       20269.0
# 4227                           574.0                       19985.0
# 542                            545.0                       19810.0
# 4048                           361.0                       19069.0
# 14016                          640.0                       18310.0
# 16421                         1311.0                       17360.0
# 431                            261.0                       17647.0
# 215                            310.0                       17505.0
# 17074                          873.0                       16640.0
# 581                          14004.0                        3263.0
# 410                            785.0                       16343.0
# 961                           1326.0                       15754.0
# 840                            822.0                       16227.0
# 44345                          551.0                       16127.0
# 555                            608.0                       15992.0
# 998                           1166.0                       15262.0
# 40119                          862.0                       15511.0
# 48597                          522.0                       15813.0
# 893                           2306.0                       13806.0
# 23384                          326.0                       15730.0
# 194                            764.0                       15241.0
# 180                            646.0                       15013.0
# 976                            455.0                       14938.0
# 19                             223.0                       15108.0
# 658                            406.0                       14914.0
# 603                            308.0                       14954.0
# 843                            521.0                       14450.0
# 575                            358.0                       14546.0
# 288                            203.0                       14698.0
# 83                           13692.0                        1068.0
# 145                            524.0                       14198.0
# 264                            313.0                       14387.0
# 789                            873.0                       13707.0
# 55                             287.0                       14228.0
# 238                            767.0                       13715.0
# 40106                          500.0                       13980.0
# 212                            527.0                       13916.0
# 323                            188.0                       14250.0
# 340                            303.0                       14099.0
# 332                            208.0                       14155.0
# 184                            387.0                       13949.0
# 266                            876.0                       13197.0
#
#       special_event_indicator held_indicator
# 23382                       N              Y
# 44337                       N              N
# 57208                       N              N
# 9347                        N              N
# 23383                       N              N
# 44343                       N              N
# 18836                       N              N
# 18834                       N              N
# 14018                       N              N
# 532                         N              Y
# 16235                       N              Y
# 44                          N              Y
# 16649                       N              Y
# 9314                        N              Y
# 27891                       N              N
# 48606                       N              N
# 40108                       N              N
# 57210                       N              N
# 554                         N              Y
# 4227                        N              N
# 542                         N              Y
# 4048                        N              N
# 14016                       N              N
# 16421                       N              Y
# 431                         N              Y
# 215                         N              Y
# 17074                       N              Y
# 581                         N              Y
# 410                         N              Y
# 961                         N              Y
# 840                         N              Y
# 44345                       N              N
# 555                         N              Y
# 998                         N              Y
# 40119                       N              N
# 48597                       N              N
# 893                         N              Y
# 23384                       N              N
# 194                         N              Y
# 180                         N              Y
# 976                         N              Y
# 19                          N              Y
# 658                         N              Y
# 603                         N              Y
# 843                         N              Y
# 575                         N              Y
# 288                         N              Y
# 83                          N              Y
# 145                         N              Y
# 264                         N              Y
# 789                         N              Y
# 55                          N              Y
# 238                         N              Y
# 40106                       N              N
# 212                         N              Y
# 323                         N              Y
# 340                         N              Y
# 332                         N              Y
# 184                         N              Y
# 266                         N              Y

# %%
time_df[(time_df['incident_datetime'] >= "2023-01-01 00:00") &(time_df['incident_datetime'] <= "2023-01-01 06:00")]
# Out:
#        incident_datetime  incident_response_seconds_qy  \
# 0    2023-01-01 00:00:02                        1887.0
# 1    2023-01-01 00:00:16                        7365.0
# 2    2023-01-01 00:00:30                         479.0
# 3    2023-01-01 00:01:35                        3725.0
# 4    2023-01-01 00:01:55                        2108.0
# ...                  ...                           ...
# 1232 2023-01-01 05:58:44                        3098.0
# 1233 2023-01-01 05:58:49                        1022.0
# 1234 2023-01-01 05:59:47                           NaN
# 1235 2023-01-01 05:59:54                           NaN
# 1236 2023-01-01 06:00:00                        2214.0
#
#       incident_travel_tm_seconds_qy  dispatch_response_seconds_qy  \
# 0                             477.0                        1410.0
# 1                            7299.0                          66.0
# 2                             365.0                         114.0
# 3                               NaN                        3725.0
# 4                             801.0                        1307.0
# ...                             ...                           ...
# 1232                          982.0                        2116.0
# 1233                          891.0                         131.0
# 1234                            NaN                           NaN
# 1235                            NaN                           NaN
# 1236                          375.0                        1839.0
#
#      special_event_indicator held_indicator
# 0                          N              N
# 1                          N              Y
# 2                          N              N
# 3                          N              N
# 4                          N              Y
# ...                      ...            ...
# 1232                       N              Y
# 1233                       N              Y
# 1234                       N              N
# 1235                       N              N
# 1236                       N              Y
#
# [1228 rows x 6 columns]

# %%
time_df.isna().sum()
# Out:
# incident_datetime                   0
# incident_response_seconds_qy     3068
# incident_travel_tm_seconds_qy    3163
# dispatch_response_seconds_qy     1208
# special_event_indicator             0
# held_indicator                      0
# dtype: int64

# %%
time_df.columns
# Out:
# Index(['incident_datetime', 'incident_response_seconds_qy',
#        'incident_travel_tm_seconds_qy', 'dispatch_response_seconds_qy',
#        'special_event_indicator', 'held_indicator'],
#       dtype='object')

# %%
time_df.isna().sum()
# Out:
# incident_datetime                   0
# incident_response_seconds_qy     3068
# incident_travel_tm_seconds_qy    3163
# dispatch_response_seconds_qy     1208
# special_event_indicator             0
# held_indicator                      0
# dtype: int64

# %%
time_df['incident_datetime'].sort_values(ascending=False)
# Out:
# 58288   2024-10-06 05:57:50
# 58184   2024-10-06 05:56:56
# 57313   2024-10-06 05:36:04
# 54278   2024-10-06 05:35:57
# 54069   2024-10-06 05:35:33
#                 ...
# 6077    2006-01-02 19:36:53
# 5431    2006-01-02 15:07:11
# 5022    2006-01-02 12:09:26
# 3997    2006-01-02 01:34:07
# 2797    2006-01-01 16:49:57
# Name: incident_datetime, Length: 60000, dtype: datetime64[ns]

# %%
time_df.columns
# Out:
# Index(['incident_datetime', 'incident_response_seconds_qy',
#        'incident_travel_tm_seconds_qy', 'dispatch_response_seconds_qy',
#        'special_event_indicator', 'held_indicator'],
#       dtype='object')

# %%
time_df['incident_datetime'].dt.year.value_counts()
# Out:
# incident_datetime
# 2023    59601
# 2006      215
# 2024       76
# 2010       50
# 2008       41
# 2012        8
# 2015        6
# 2009        1
# 2016        1
# 2007        1
# Name: count, dtype: int64

# %%
time_df['incident_datetime'].value_counts()
# Out:
# incident_datetime
# 2023-01-11 16:01:11    3
# 2023-01-13 15:51:18    3
# 2023-01-13 12:40:40    3
# 2023-01-13 10:16:09    3
# 2023-01-04 17:42:00    3
#                       ..
# 2023-01-05 10:15:32    1
# 2023-01-05 10:15:42    1
# 2023-01-05 10:15:50    1
# 2024-10-05 16:09:07    1
# 2023-01-14 18:14:35    1
# Name: count, Length: 58615, dtype: int64

# %%
time_df.groupby(time_df["incident_datetime"].dt.year).apply(lambda x: x.isna().sum())
# Out:
#                    incident_datetime  incident_response_seconds_qy  \
# incident_datetime
# 2006                               0                            90
# 2007                               0                             0
# 2008                               0                             9
# 2009                               0                             1
# 2010                               0                            13
# 2012                               0                             7
# 2015                               0                             1
# 2016                               0                             1
# 2023                               0                          2933
# 2024                               0                            13
#
#                    incident_travel_tm_seconds_qy  \
# incident_datetime
# 2006                                          91
# 2007                                           0
# 2008                                          10
# 2009                                           1
# 2010                                          12
# 2012                                           7
# 2015                                           1
# 2016                                           1
# 2023                                        3027
# 2024                                          13
#
#                    dispatch_response_seconds_qy  special_event_indicator  \
# incident_datetime
# 2006                                         42                        0
# 2007                                          0                        0
# 2008                                          5                        0
# 2009                                          1                        0
# 2010                                          7                        0
# 2012                                          7                        0
# 2015                                          0                        0
# 2016                                          1                        0
# 2023                                       1140                        0
# 2024                                          5                        0
#
#                    held_indicator
# incident_datetime
# 2006                            0
# 2007                            0
# 2008                            0
# 2009                            0
# 2010                            0
# 2012                            0
# 2015                            0
# 2016                            0
# 2023                            0
# 2024                            0

# %%
na2006 =time_df[time_df['incident_datetime'].dt.year==2006]

# %%
na2006['incident_response_seconds_qy'].median()
# Out:
# np.float64(412.0)

# %%
na2006['inc'] = na2006['incident_response_seconds_qy'].fillna(na2006['incident_response_seconds_qy'].median())
# Out:
# /var/folders/34/1yg1tqgd1b96v45w9k29prnw0000gn/T/ipykernel_71278/848369191.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   na2006['inc'] = na2006['incident_response_seconds_qy'].fillna(na2006['incident_response_seconds_qy'].median())

# %%
na2006.sort_values('incident_response_seconds_qy',ascending=False).head(5)
# Out:
#         incident_datetime  incident_response_seconds_qy  \
# 34067 2006-01-12 00:47:29                        1238.0
# 46517 2006-01-16 06:55:40                        1172.0
# 25961 2006-01-09 11:56:15                        1140.0
# 19352 2006-01-07 02:50:00                        1126.0
# 45227 2006-01-15 17:58:11                        1095.0
#
#        incident_travel_tm_seconds_qy  dispatch_response_seconds_qy  \
# 34067                         1215.0                          23.0
# 46517                         1049.0                         123.0
# 25961                         1125.0                          15.0
# 19352                         1081.0                          45.0
# 45227                          972.0                         123.0
#
#       special_event_indicator held_indicator     inc
# 34067                       N              N  1238.0
# 46517                       N              N  1172.0
# 25961                       N              N  1140.0
# 19352                       N              N  1126.0
# 45227                       N              N  1095.0

# %%
na2006['inc'].isna().sum()
# Out:
# np.int64(0)

# %%
na2006['inc']
# Out:
# 2797     412.0
# 3997     204.0
# 5022     222.0
# 5431     412.0
# 6077     412.0
#          ...
# 57815    412.0
# 58020    412.0
# 58667    365.0
# 59177    412.0
# 59483    262.0
# Name: inc, Length: 215, dtype: float64

# %%
time_df.isna().sum()
# Out:
# incident_datetime                   0
# incident_response_seconds_qy     2978
# incident_travel_tm_seconds_qy    3163
# dispatch_response_seconds_qy     1208
# special_event_indicator             0
# held_indicator                      0
# dtype: int64

# %%
time_df.loc[time_df['incident_datetime'].dt.year == 2006,'incident_response_seconds_qy'] = na2006['inc'].values

# %%
time_df[time_df['incident_datetime'].dt.year==2006].isna().sum()
# Out:
# incident_datetime                 0
# incident_response_seconds_qy      0
# incident_travel_tm_seconds_qy    91
# dispatch_response_seconds_qy     42
# special_event_indicator           0
# held_indicator                    0
# dtype: int64

# %%
na2006['incident_travel_tm'] = na2006['incident_travel_tm_seconds_qy'].fillna(na2006['incident_travel_tm_seconds_qy'].median())
# Out:
# /var/folders/34/1yg1tqgd1b96v45w9k29prnw0000gn/T/ipykernel_71278/121650811.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   na2006['incident_travel_tm'] = na2006['incident_travel_tm_seconds_qy'].fillna(na2006['incident_travel_tm_seconds_qy'].median())

# %%
time_df[time_df['incident_datetime'].dt.year==2006].describe()
# Out:
#                    incident_datetime  incident_response_seconds_qy  \
# count                            215                    215.000000
# mean   2006-01-11 10:54:46.423255808                    447.409302
# min              2006-01-01 16:49:57                     49.000000
# 25%              2006-01-06 20:00:36                    373.000000
# 50%              2006-01-11 18:26:05                    412.000000
# 75%       2006-01-15 13:54:28.500000                    455.500000
# max              2006-01-20 13:36:01                   1238.000000
# std                              NaN                    193.770531
#
#        incident_travel_tm_seconds_qy  dispatch_response_seconds_qy
# count                     124.000000                    173.000000
# mean                      427.459677                     66.219653
# min                        32.000000                      5.000000
# 25%                       259.500000                     19.000000
# 50%                       371.500000                     34.000000
# 75%                       551.500000                     68.000000
# max                      1215.000000                   1217.000000
# std                       232.173764                    129.896686

# %%
time_df.columns
# Out:
# Index(['incident_datetime', 'incident_response_seconds_qy',
#        'incident_travel_tm_seconds_qy', 'dispatch_response_seconds_qy',
#        'special_event_indicator', 'held_indicator'],
#       dtype='object')

# %%
time_df['incident_response_seconds_qy'] = (time_df.groupby(time_df['incident_datetime'].dt.year)['incident_response_seconds_qy'].transform(lambda x: x.fillna(x.median())))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/numpy/lib/_nanfunctions_impl.py:1213: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/numpy/lib/_nanfunctions_impl.py:1213: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)

# %%
time_df['incident_response_seconds_qy'].isna().sum()
# Out:
# np.int64(2)

# %%
time_df.loc[time_df['incident_response_seconds_qy'].isna(), 'incident_datetime'].dt.year
# Out:
# 2253    2009
# 4440    2016
# Name: incident_datetime, dtype: int32
